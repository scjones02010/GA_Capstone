# %% [markdown]
# Necessary imports for missing value imputation.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataframe for work.

# %%
df_for_nan_impute=pd.read_csv('../Data/movies_data_complete.csv',index_col='Unnamed: 0')
df_for_nan_impute.sample(10)
# Out:
#             id  popularity  runtime  video  vote_average  vote_count  \
# 89458    38849    1.295139     80.0      0           5.6        18.0
# 428255  369567    0.001648    121.0      0           0.0         0.0
# 195138   51472    0.355919     25.0      0           6.8         6.0
# 103838   59809    0.522987     89.0      0           5.6         4.0
# 443120  371084    0.266603     60.0      0           6.0         3.0
# 178070    1874   10.480169    140.0      0           7.0        38.0
# 421329  407897    0.051763     70.0      0           0.0         0.0
# 132525   29142    1.838729     91.0      0           6.2        11.0
# 363062  233564    1.231539     93.0      0           2.8         8.0
# 377598   32160    1.898149    124.0      0           6.2        10.0
#
#         release_year  release_month  release_day  has_homepage  ...  \
# 89458           1982             10           15             0  ...
# 428255          1947              2            3             0  ...
# ...

# %% [markdown]
# Unnecessary columns are dropped.

# %%
df_for_nan_impute.drop(columns=['movie_id_x','movie_id_y'],inplace=True)

# %%
df_for_nan_impute.shape
# Out:
# (44674, 136)

# %% [markdown]
# Missing values are showen and information needed to be able to analyze. The ratings columns are dropped due the vast amount being null and there is no ability to  impute the values correctly.

# %%
dict(df_for_nan_impute.isna().sum())
# Out:
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %%
df_for_nan_impute.drop(columns=['max_rating','min_rating','median_rating','average_rating','mode_rating'],inplace=True)

# %%
print(df_for_nan_impute.shape)
dict(df_for_nan_impute.isna().sum())
# Out:
# (44674, 131)
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %% [markdown]
# The overview and tagline missing values were zero because this are NA due to these values not existing for the film.

# %%
df_for_nan_impute.loc[df_for_nan_impute['overview_negative_sentiment_score'].isna()==True,'overview_negative_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['overview_neutral_sentiment_score'].isna()==True,'overview_neutral_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['overview_positive_sentiment_score'].isna()==True,'overview_positive_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['overview_compound_sentiment_score'].isna()==True,'overview_compound_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['overview_length'].isna()==True,'overview_length']=0
df_for_nan_impute.loc[df_for_nan_impute['tagline_negative_sentiment_score'].isna()==True,'tagline_negative_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['tagline_neutral_sentiment_score'].isna()==True,'tagline_neutral_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['tagline_positive_sentiment_score'].isna()==True,'tagline_positive_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['tagline_compound_sentiment_score'].isna()==True,'tagline_compound_sentiment_score']=0
df_for_nan_impute.loc[df_for_nan_impute['tagline_length'].isna()==True,'tagline_length']=0

# %%
print(df_for_nan_impute.shape)
dict(df_for_nan_impute.isna().sum())
# Out:
# (44674, 131)
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %%
print(df_for_nan_impute.shape)
dict(df_for_nan_impute.isna().sum())
# Out:
# (44674, 131)
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %% [markdown]
# For the missing crew information, a selective mean imputation was used for each associated genre. The logic is that films produced by a similar genre and studio will have similar budgets. This logic will understate the variance, but will keep the variance withing a logical understanding.

# %%
total_crew_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'total_movie_crew'].mean()
total_crew_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_family']==1),'total_movie_crew'].mean()
total_crew_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'total_movie_crew'].mean()
total_crew_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'total_movie_crew'].mean()
total_crew_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_romance']==1),'total_movie_crew'].mean()
total_crew_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_crime']==1),'total_movie_crew'].mean()
total_crew_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'total_movie_crew'].mean()
total_crew_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'total_movie_crew'].mean()
total_crew_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'total_movie_crew'].mean()
total_crew_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_music']==1),'total_movie_crew'].mean()
total_crew_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_horror']==1),'total_movie_crew'].mean()
total_crew_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_war']==1),'total_movie_crew'].mean()
total_crew_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'total_movie_crew'].mean()
total_crew_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'total_movie_crew'].mean()
total_crew_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'total_movie_crew'].mean()
total_crew_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_history']==1),'total_movie_crew'].mean()
total_crew_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_western']==1),'total_movie_crew'].mean()
total_crew_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_action']==1),'total_movie_crew'].mean()
total_crew_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False)&(df_for_nan_impute['is_animation']==1),'total_movie_crew'].mean()
total_crew_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==False),'total_movie_crew'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'total_movie_crew']=total_crew_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_family']==1),'total_movie_crew']=total_crew_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'total_movie_crew']=total_crew_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'total_movie_crew']=total_crew_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_romance']==1),'total_movie_crew']=total_crew_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_crime']==1),'total_movie_crew']=total_crew_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'total_movie_crew']=total_crew_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'total_movie_crew']=total_crew_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'total_movie_crew']=total_crew_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_music']==1),'total_movie_crew']=total_crew_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_horror']==1),'total_movie_crew']=total_crew_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_war']==1),'total_movie_crew']=total_crew_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'total_movie_crew']=total_crew_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'total_movie_crew']=total_crew_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'total_movie_crew']=total_crew_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_history']==1),'total_movie_crew']=total_crew_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_western']==1),'total_movie_crew']=total_crew_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_action']==1),'total_movie_crew']=total_crew_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True)&(df_for_nan_impute['is_animation']==1),'total_movie_crew']=total_crew_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_crew'].isna()==True),'total_movie_crew']=total_crew_mean_impute

# %%
second_most_used_crew_member_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_most_used_crew_member_per_movie'].mean()
second_most_used_crew_member_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==False),'second_most_used_crew_member_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_crew_member_per_movie'].isna()==True),'second_most_used_crew_member_per_movie']=second_most_used_crew_member_per_movie_mean_impute

# %%
most_used_crew_member_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'most_used_crew_member_per_movie'].mean()
most_used_crew_member_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==False),'most_used_crew_member_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['most_used_crew_member_per_movie'].isna()==True),'most_used_crew_member_per_movie']=most_used_crew_member_per_movie_mean_impute

# %%
second_least_used_crew_member_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_least_used_crew_member_per_movie'].mean()
second_least_used_crew_member_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==False),'second_least_used_crew_member_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_crew_member_per_movie'].isna()==True),'second_least_used_crew_member_per_movie']=second_least_used_crew_member_per_movie_mean_impute

# %%
least_used_crew_member_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'least_used_crew_member_per_movie'].mean()
least_used_crew_member_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==False),'least_used_crew_member_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['least_used_crew_member_per_movie'].isna()==True),'least_used_crew_member_per_movie']=least_used_crew_member_per_movie_mean_impute

# %%
dict(df_for_nan_impute.isna().sum())
# Out:
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %% [markdown]
# For the missing cast information, a selective mean imputation was used for each associated genre. The logic is that films produced by a similar genre and studio will have similar budgets. This logic will understate the variance, but will keep the variance withing a logical understanding.

# %%
total_cast_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'total_cast_per_movie'].mean()
total_cast_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==False),'total_cast_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'total_cast_per_movie']=total_cast_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['total_cast_per_movie'].isna()==True),'total_cast_per_movie']=total_cast_per_movie_mean_impute

# %%
most_used_actor_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'most_used_actor_per_movie'].mean()
most_used_actor_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==False),'most_used_actor_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['most_used_actor_per_movie'].isna()==True),'most_used_actor_per_movie']=most_used_actor_per_movie_mean_impute

# %%
second_most_used_actor_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_most_used_actor_per_movie'].mean()
second_most_used_actor_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==False),'second_most_used_actor_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_actor_per_movie'].isna()==True),'second_most_used_actor_per_movie']=second_most_used_actor_per_movie_mean_impute

# %%
second_least_used_actor_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_least_used_actor_per_movie'].mean()
second_least_used_actor_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==False),'second_least_used_actor_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_actor_per_movie'].isna()==True),'second_least_used_actor_per_movie']=second_least_used_actor_per_movie_mean_impute

# %%
least_used_actor_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'least_used_actor_per_movie'].mean()
least_used_actor_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==False),'least_used_actor_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['least_used_actor_per_movie'].isna()==True),'least_used_actor_per_movie']=least_used_actor_per_movie_mean_impute

# %%
dict(df_for_nan_impute.isna().sum())
# Out:
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %% [markdown]
# For the missing keyword information, a selective mean imputation was used for each associated genre. The logic is that films produced by a similar genre and studio will have similar budgets. This logic will understate the variance, but will keep the variance withing a logical understanding.

# %%
total_movie_keywords_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_family']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_romance']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_crime']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_music']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_horror']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_war']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_history']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_western']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_action']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_animation']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'total_movie_keywords'].mean()
total_movie_keywords_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==False),'total_movie_keywords'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_family']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_romance']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_crime']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_music']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_horror']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_war']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_history']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_western']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_action']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_animation']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'total_movie_keywords']=total_movie_keywords_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['total_movie_keywords'].isna()==True),'total_movie_keywords']=total_movie_keywords_mean_impute

# %%
most_used_keywords_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'most_used_keywords_per_movie'].mean()
most_used_keywords_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==False),'most_used_keywords_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['most_used_keywords_per_movie'].isna()==True),'most_used_keywords_per_movie']=most_used_keywords_per_movie_mean_impute

# %%
second_most_used_keywords_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_most_used_keywords_per_movie'].mean()
second_most_used_keywords_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==False),'second_most_used_keywords_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_most_used_keywords_per_movie'].isna()==True),'second_most_used_keywords_per_movie']=second_most_used_keywords_per_movie_mean_impute

# %%
second_least_used_keywords_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'second_least_used_keywords_per_movie'].mean()
second_least_used_keywords_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==False),'second_least_used_keywords_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['second_least_used_keywords_per_movie'].isna()==True),'second_least_used_keywords_per_movie']=second_least_used_keywords_per_movie_mean_impute

# %%
least_used_keywords_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'least_used_keywords_per_movie'].mean()
least_used_keywords_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==False),'least_used_keywords_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['least_used_keywords_per_movie'].isna()==True),'least_used_keywords_per_movie']=least_used_keywords_per_movie_mean_impute

# %%
average_keyword_negative_sentiment_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'average_keyword_negative_sentiment_per_movie'].mean()
average_keyword_negative_sentiment_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==False),'average_keyword_negative_sentiment_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_negative_sentiment_per_movie'].isna()==True),'average_keyword_negative_sentiment_per_movie']=average_keyword_negative_sentiment_per_movie_mean_impute

# %%
average_keyword_neutral_sentiment_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'average_keyword_neutral_sentiment_per_movie'].mean()
average_keyword_neutral_sentiment_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==False),'average_keyword_neutral_sentiment_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_neutral_sentiment_per_movie'].isna()==True),'average_keyword_neutral_sentiment_per_movie']=average_keyword_neutral_sentiment_per_movie_mean_impute

# %%
average_keyword_postive_sentiment_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'average_keyword_postive_sentiment_per_movie'].mean()
average_keyword_postive_sentiment_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==False),'average_keyword_postive_sentiment_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_postive_sentiment_per_movie'].isna()==True),'average_keyword_postive_sentiment_per_movie']=average_keyword_postive_sentiment_per_movie_mean_impute

# %%
average_keyword_compound_sentiment_per_movie_mean_impute_comedy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_comedy']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_family=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_family']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_adventure=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_adventure']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_fantasy=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_romance=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_romance']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_crime=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_crime']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_thriller=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_thriller']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_science_fiction=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_music=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_music']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_horror=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_horror']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_war=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_war']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_documentary=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_documentary']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_foreign=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_foreign']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_tv_movie=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_history=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_history']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_western=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_western']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_action=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_action']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_animation=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_animation']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute_mystery=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False)&(df_for_nan_impute['is_mystery']==1),'average_keyword_compound_sentiment_per_movie'].mean()
average_keyword_compound_sentiment_per_movie_mean_impute=df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==False),'average_keyword_compound_sentiment_per_movie'].mean()

# %%
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_comedy']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_comedy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_family']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_family
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_adventure']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_adventure
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_fantasy']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_fantasy
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_romance']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_romance
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_crime']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_crime
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_thriller']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_thriller
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_science_fiction']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_science_fiction
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_music']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_music
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_horror']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_horror
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_war']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_war
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_documentary']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_documentary
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_foreign']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_foreign
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_tv_movie']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_tv_movie
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_history']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_history
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_western']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_western
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_action']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_action
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_animation']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_animation
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True)&(df_for_nan_impute['is_mystery']==1),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute_mystery
df_for_nan_impute.loc[(df_for_nan_impute['average_keyword_compound_sentiment_per_movie'].isna()==True),'average_keyword_compound_sentiment_per_movie']=average_keyword_compound_sentiment_per_movie_mean_impute

# %%
dict(df_for_nan_impute.isna().sum())
# Out:
# {'id': 0,
#  'popularity': 0,
#  'runtime': 0,
#  'video': 0,
#  'vote_average': 0,
#  'vote_count': 0,
#  'release_year': 0,
#  'release_month': 0,
#  'release_day': 0,
#  'has_homepage': 0,
#  'is_in_series': 0,
#  'has_tagline': 0,
#  'has_poster': 0,
#  'has_overview': 0,
#  'is_animation': 0,
#  'is_comedy': 0,
#  'is_family': 0,
#  'is_adventure': 0,
#  'is_fantasy': 0,
#  'is_romance': 0,
#  'is_crime': 0,
#  'is_thriller': 0,
#  'is_mystery': 0,
#  'is_science_fiction': 0,
#  'is_music': 0,
#  'is_horror': 0,
#  'is_war': 0,
#  'is_documentary': 0,
#  'is_foreign': 0,
#  'is_tv_movie': 0,
#  'is_history': 0,
#  'is_drama': 0,
#  'is_western': 0,
#  'is_action': 0,
#  'produced_by_warner_bros': 0,
#  'produced_by_mgm': 0,
#  'produced_by_paramount_pictures': 0,
#  'produced_by_20th_century_fox_film_corp': 0,
#  'produced_by_universal_pictures': 0,
#  'produced_by_columbia_pictures_corp': 0,
#  'produced_by_canal': 0,
#  'produced_by_columbia_pictures': 0,
# ...

# %%
df_for_nan_impute.sample(20)
# Out:
#             id  popularity  runtime  video  vote_average  vote_count  \
# 183820   13405   14.622493    125.0      0           6.5        53.0
# 448005  424488   11.852169    116.0      0           7.1       101.0
# 205935  114790    0.441521     99.0      0           7.8         3.0
# 458332   87952    0.132897     78.0      0           6.7         3.0
# 425945  414719   14.567726     93.0      0           4.7        23.0
# 406641   20898    1.202725     84.0      0           5.4         4.0
# 253404   71668    5.615205     83.0      0           4.1       319.0
# 4232     20156    5.378467    103.0      0           6.5        64.0
# 361464  158182    0.490065    109.0      0           6.0         4.0
# 459692  448992    0.001414     14.0      0           0.0         0.0
# 245993  126016    0.007134     60.0      0           0.0         0.0
# 252131   45945    0.107973    104.0      0           5.0         1.0
# 428313  370765    1.029507     79.0      0           4.0        17.0
# ...

# %% [markdown]
# The columns are renamed for better description and then the data frame is exported for modeling information.

# %%
df_for_nan_impute.rename(columns={'most_used_crew_member_per_movie': 'number_of_A_list_crew_members_per_movie',
 'second_most_used_crew_member_per_movie': 'number_of_B_list_crew_members_per_movie',
 'second_least_used_crew_member_per_movie': 'number_of_C_list_crew_members_per_movie',
 'least_used_crew_member_per_movie': 'number_of_D_list_crew_members_per_movie',
 'most_used_actor_per_movie': 'number_of_A_list_cast_members_per_movie',
 'second_most_used_actor_per_movie': 'number_of_B_list_cast_members_per_movie',
 'second_least_used_actor_per_movie': 'number_of_C_list_cast_members_per_movie',
 'least_used_actor_per_movie': 'number_of_D_list_cast_members_per_movie'},inplace=True)

# %%
df_for_nan_impute.to_csv('../Data/movies_data_for_modeling.csv')
